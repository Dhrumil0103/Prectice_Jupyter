# %%
import matplotlib
import numpy as np

# %%
print(matplotlib.__version__)
# Out:
# 3.5.2

# %%
import matplotlib.pyplot as plt

# %%
print(plt.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26572\440707483.py in <module>
# ----> 1 print(plt.__version__)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
print(np.__version__)
# Out:
# 1.21.5

# %%
er = np.array([3,4,8,1])
we = np.array([7,1,6,9])

plt.plot(er,we)
plt.show()

# %%
bn = np.array([5,9])
yu = np.array([2,6])

plt.plot(bn,yu)
plt.show()

# %%
bn1 = np.array([5,3])
yu1 = np.array([2,4])

plt.plot(bn1, yu1, "o")
plt.show()

# %%
hj = np.array([5,8,1,5])

plt.plot(hj)
plt.show()

# %%
b1 = np.array([5,3])
n1 = np.array([2,4])

plt.plot(b1,n1,"$")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26572\979628385.py in <module>
#       2 n1 = np.array([2,4])
#       3
# ----> 4 plt.plot(b1,n1,"$")
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
bv = np.array([5,3])
cv = np.array([2,4])

plt.plot(bv, cv, marker = "*")
plt.show()

# %%
nm = np.array([4,6,1,5])

plt.plot(nm, linestyle = "--", marker = "*")
plt.show()
